# %% [markdown]
# # Resumen de los datos, dimensiones y estructuras

# %%
import pandas as pd
import os

# %%
mainpath = '/home/eligiuz/python-ml-course/datasets'
filename = 'titanic/titanic3.csv'
fullpath = os.path.join(mainpath, filename) # Con esto te une los dos valores en uno solo sin espacios

# %%
data = pd.read_csv(fullpath)

# %%
data.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
data.shape # para saber cuantas filas y columnas tiene el dataframe, la forma
# Out:
# (1309, 14)

# %%
data.columns.values # para obtener un array de los nombres de las columnas
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# Resúmen de las estadísticas de las variables numéricas

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.dtypes # para saber con que tipos de datos estamos trabajando y saber como manejarlos
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# # Valores faltantes

# %%
pd.isnull(data['body']) # Para saber cuantos NaN hay en la columna especificada
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
pd.notnull(data['body']) # lo mismo que el anterior pero buscando los que no son nulos o NaN
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307    False
# 1308    False
# Name: body, Length: 1309, dtype: bool

# %%
pd.isnull(data['body']).values.sum() # Cuenta las celdas que tienen NaN y da como valor(values) TRUE y con sum() los cuenta
# Out:
# 1188

# %%
pd.notnull(data['body']).values.sum() # lo mismo que el anterior pero en este me cuenta los que no tienen NaN
# Out:
# 121

# %% [markdown]
# Los valores que faltan en un data set pueden venir por dos razones:
# * Extracción de los datos. - Problemas en la extracción de los datos
# * Recolección de los datos. - Debido a que no se tiene ese valor porque se decidio no ponerlo o que no es necesario.

# %% [markdown]
# #### Borrado de valores que faltan

# %%
data.dropna(axis=0, how='all')  # Si axis = 0 se borra toda una fila axis = 1 borra toda la columna donde hay NaN how='' cuales debe borra. all-> si todas susu columnas tienen NaN
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data2 = data

# %%
data.dropna(axis=0, how='any') # con how='any' elimina las filas que contengan al menos un NaN
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# #### Cómputo de los valores faltantes

# %%
data3 = data

# %%
data3.fillna(0) # con esto relleno todos los NaN con ceros
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data4 = data

# %%
data4 = data4.fillna('Desconocido') # en este caso coloco la palabra desconocido en donde existe NaN

# %%
data5 = data

# %%
data5['body'] = data5['body'].fillna(0) # con esto rellenamos con "0" aquellas celdas que aparecen con NaN en la columna 'body'
data5['home.dest'] = data5['home.dest'].fillna('Desconocido') # con esto rellenamos con "Desconocido" aquellas celdas que aparecen con NaN en la columna 'hoome.dest'
data5.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body    home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0  Desconocido
# 1305    2665  14.4542   NaN        C  NaN    0.0  Desconocido
# 1306    2656   7.2250   NaN        C  NaN  304.0  Desconocido
# 1307    2670   7.2250   NaN        C  NaN    0.0  Desconocido
# 1308  315082   7.8750   NaN        S  NaN    0.0  Desconocido

# %%
pd.isnull(data5['age']).values.sum() # Se revisa cuantos valores no existen en la columna 'age'
# Out:
# 263

# %%
data5['age'].fillna(data5['age'].mean()) # se rellenan las celdas donde aparece Nan en la columna age con la media de la misma utilizando la función mean()
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# 1306    26.500000
# 1307    27.000000
# 1308    29.000000
# Name: age, Length: 1309, dtype: float64

# %%
data5['age'][1305]
# Out:
# nan

# %%
data5['age'].fillna(method='ffill') # Sustituye con el valor mas cercano hacia arriba en el indice de la celda que contenga NaN
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
data5['age'].fillna(method='backfill') #Hace los mismo que el anteriro pero con el valor mas cercano hacia abajo
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    26.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %% [markdown]
# # Variables dummy
# Es un procerso para crear variables para cada catgoría en una variable categorica

# %%
data['sex']
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
dummy_sex = pd.get_dummies(data['sex'], prefix='sex') # crea las variables dummy de columna "sex" separandolos y su nombre de columna tiene el prefijo "sex"

# %%
dummy_sex.head()
# Out:
#    sex_female  sex_male
# 0           1         0
# 1           0         1
# 2           1         0
# 3           0         1
# 4           1         0

# %%
column_name = data.columns.values.tolist() # para ver en una lista todas las columnas
column_name
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
data.drop(['sex'], axis=1) # elimina la columa "sex" al poner el axis=1
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
pd.concat([data,dummy_sex], axis=1) # Ahregamos con "concat" las columnas creadas y que están en la variabñle dummy_sex al dataframe
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
def createDummies(df, var_name):
    dummy = pd.get_dummies(df[var_name], prefix=var_name)
    df = df.drop(var_name, axis=1)
    df = pd.concat([df, dummy], axis=1)
    return df

# %%
createDummies(data3, 'sex')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...
